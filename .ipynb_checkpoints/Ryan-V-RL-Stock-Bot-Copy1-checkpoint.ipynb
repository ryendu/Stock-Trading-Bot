# %% [markdown]
# ## Stock Bot
# Okay Im gonna make a DIY stock trading, reinforcment learning bot on my own with preferably only tensorflow, numpy, and padas. I actually have no idea how to do that, sooo lets try it out!
#
# ### Planning
# I need to have the following items built
# - the environment
# - the agent
# - memory for the agent
# - the policy for the agent
# - the neural net for the agent
#
# TODO: Train and wth is wrong with the probabilities contain nAn for training

# %%
from tensorflow import keras
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import yfinance as yf
import gym_anytrading
from StockTradeEnv import FastTrainingStockTradeEnv
from LowRegulationStockTradeEnv import LowRegulationStockTradeEnv
import quantstats as qs
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Input, Activation, Concatenate
from tensorflow.keras.optimizers import Adam
from stable_baselines3 import PPO, A2C
from stable_baselines3.ppo.policies import MlpPolicy as MlpPolicyPPO
from stable_baselines3.a2c.policies import MlpPolicy as MlpPolicyA2C
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv,SubprocVecEnv,VecEnv
from Utilities import eval_model
from Utilities import plot_history
from LSTMPolicy import LSTMActorCriticPolicy,CustomLSTM
import torch
from torch import nn

# %% [markdown]
# ## Environment
# The environment will contain the observable variables:
#     -
#     -
# The environment will contain the avalible actions of:
#     -
#     -
#     -

# %%
# Parallel environments
stks = ['kros','nflx']#,'tmus','adct','h','bngo','amzn','nio','fb','gme','work','irbt','upwk','fvrr','rdfn','bynd','etsy','pins','zg','roku','sq','pm','dis','nlok','bio','gbio']
# env = DummyVecEnv([lambda: FastTrainingStockTradeEnv(ticker=stks[i],frame_bound=(100, 100000), window_size=10,initial_balance=25000,verbose=0,obs_dim=3) for i in range(len(stks))])
env = DummyVecEnv([lambda: LowRegulationStockTradeEnv(ticker=stks[i],frame_bound=(100, 100000), window_size=10,initial_balance=25000,verbose=2) for i in range(len(stks))])
# Out:
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
model_ppo = PPO(MlpPolicyPPO, env, verbose=0)
model_a2c = A2C(MlpPolicyA2C, env, verbose=0)

# %%
model_ppo=model_ppo.learn(10)
model_a2c=model_ppo.learn(10)
# Out:
#  0.7690417]
#         nflx: Held, networth: 25238.852142751217, shares: 9
#        step reward: -6.134149360656738
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.2165529429912567
# Step: 2026 ----------------------
# ACTION GOT: [0.        0.        0.        1.9145103], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25706.237162292004, shares: 39
#        step reward: -26.5813138961792
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 1.9145102500915527
# Step: 2027 ----------------------
# ACTION GOT: [1.         0.89905274 0.939188   0.2660786 ], action type one hot: [1.         0.89905274 0.939188  ]
#         nflx: Held, networth: 25234.133566319942, shares: 9
#        step reward: 6.3848470687866214
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.2660785913467407
# Step: 2027 ----------------------
# ACTION GOT: [0.         0.49970108 0.         1.225619  ], action type one hot: [0.         0.49970108 0.        ]
# ACTION VALUE: 1.2256189584732056
#         nflx: Bought 1 stock(s) for:21.878570556640625, networth: 25685.78999775648, shares: 40
#        step reward: 27.667670631408694
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 1.2256189584732056
# Step: 2028 ----------------------
# ACTION GOT: [0.         0.         0.37543362 0.94838846], action type one hot: [0.         0.         0.37543362]
#         nflx: Sold 1 stock(s) for:24.670000076293945,networth: 25239.044987142086, shares: 8
#        step reward: 32.65972537994385
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.9483884572982788
# Step: 2028 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25707.072821319103, shares: 40
#        step reward: 145.15433502197266
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2029 ----------------------
# ACTION GOT: [0.        1.        0.        1.9346303], action type one hot: [0. 1. 0.]
# ACTION VALUE: 1.934630274772644
#         nflx: Bought 2 stock(s) for:24.014286041259766, networth: 25264.167852818966, shares: 10
#        step reward: -6.819425964355469
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 1.934630274772644
# Step: 2029 ----------------------
# ACTION GOT: [0.7702864 0.        0.9302377 0.       ], action type one hot: [0.7702864 0.        0.9302377]
#         Tried to Sell. Unable.
#        step reward: -34.097129821777344
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2030 ----------------------
# ACTION GOT: [0.39223272 0.05028855 1.         0.        ], action type one hot: [0.39223272 0.05028855 1.        ]
#         Tried to Sell. Unable.
#        step reward: -2.3400039672851562
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2030 ----------------------
# ACTION GOT: [0.8075801 0.        0.3932019 0.       ], action type one hot: [0.8075801 0.        0.3932019]
#         nflx: Held, networth: 25792.50144070387, shares: 40
#        step reward: -9.360015869140625
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2031 ----------------------
# ACTION GOT: [0.46269172 0.         0.99418396 0.3420822 ], action type one hot: [0.46269172 0.         0.99418396]
#         Tried to Sell. Unable.
#        step reward: 20.02001190185547
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.3420822024345398
# Step: 2031 ----------------------
# ACTION GOT: [0. 1. 0. 0.], action type one hot: [0. 1. 0.]
# ACTION VALUE: 0.0
#         Tried to Buy. Unable.
#        step reward: 80.08004760742188
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.0
# Step: 2032 ----------------------
# ACTION GOT: [0.        0.3437629 0.        0.       ], action type one hot: [0.        0.3437629 0.       ]
# ACTION VALUE: 0.0
#         Tried to Buy. Unable.
#        step reward: 1.6342735290527344
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.0
# Step: 2032 ----------------------
# ACTION GOT: [0.         0.00297233 0.97767    0.5576501 ], action type one hot: [0.         0.00297233 0.97767   ]
#         nflx: Sold 1 stock(s) for:25.5,networth: 25846.90146511793, shares: 39
#        step reward: 6.5370941162109375
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.557650089263916
# Step: 2033 ----------------------
# ACTION GOT: [0.        0.        0.        0.8207886], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25273.779280126095, shares: 10
#        step reward: -5.199995040893555
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.8207886219024658
# Step: 2033 ----------------------
# ACTION GOT: [0.8821992  1.         0.         0.31501627], action type one hot: [0.8821992 1.        0.       ]
# ACTION VALUE: 0.3150162696838379
#         Tried to Buy. Unable.
#        step reward: -20.279980659484863
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.3150162696838379
# Step: 2034 ----------------------
# ACTION GOT: [1.        0.        1.        0.8479497], action type one hot: [1. 0. 1.]
#         nflx: Held, networth: 25269.779283940792, shares: 10
#        step reward: -3.955730438232422
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.8479496836662292
# Step: 2034 ----------------------
# ACTION GOT: [0.33065748 0.         0.45936674 0.        ], action type one hot: [0.33065748 0.         0.45936674]
#         Tried to Sell. Unable.
#        step reward: -15.427348709106445
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2035 ----------------------
# ACTION GOT: [0.4748707  0.47535402 0.         0.32630017], action type one hot: [0.4748707  0.47535402 0.        ]
# ACTION VALUE: 0.32630017399787903
#         Tried to Buy. Unable.
#        step reward: -11.514276504516602
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.32630017399787903
# Step: 2035 ----------------------
# ACTION GOT: [0.8565426  0.         1.         0.12224309], action type one hot: [0.8565426 0.        1.       ]
#         Tried to Sell. Unable.
#        step reward: -44.90567836761475
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.12224309146404266
# Step: 2036 ----------------------
# ACTION GOT: [0.         0.         1.         0.30759418], action type one hot: [0. 0. 1.]
#         Tried to Sell. Unable.
#        step reward: 7.874292373657227
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.3075941801071167
# Step: 2036 ----------------------
# ACTION GOT: [1.         0.28061232 0.18584621 0.01624086], action type one hot: [1.         0.28061232 0.18584621]
#         nflx: Held, networth: 25789.91999310255, shares: 39
#        step reward: 30.709740257263185
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.016240861266851425
# Step: 2037 ----------------------
# ACTION GOT: [0.         0.         0.         0.22485983], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25263.936426579952, shares: 10
#        step reward: -0.2785778045654297
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.2248598337173462
# Step: 2037 ----------------------
# ACTION GOT: [0.         0.15146914 0.66027987 0.        ], action type one hot: [0.         0.15146914 0.66027987]
#         Tried to Sell. Unable.
#        step reward: -1.0864534378051758
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2038 ----------------------
# ACTION GOT: [0.1559475 0.        0.        0.       ], action type one hot: [0.1559475 0.        0.       ]
#         nflx: Held, networth: 25263.722135961056, shares: 10
#        step reward: -6.760005950927734
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2038 ----------------------
# ACTION GOT: [0.        0.        0.        1.6621631], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25812.707136809826, shares: 39
#        step reward: -26.364023208618164
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 1.6621631383895874
# Step: 2039 ----------------------
# ACTION GOT: [1. 0. 0. 0.], action type one hot: [1. 0. 0.]
#         nflx: Held, networth: 25258.52213138342, shares: 10
#        step reward: 0.5200119018554688
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2039 ----------------------
# ACTION GOT: [0.80119425 0.         0.         0.        ], action type one hot: [0.80119425 0.         0.        ]
#         nflx: Held, networth: 25792.427118957043, shares: 39
#        step reward: 2.0280464172363284
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2040 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25258.922140538692, shares: 10
#        step reward: 1.912851333618164
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2040 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25793.98715466261, shares: 39
#        step reward: 7.46012020111084
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2041 ----------------------
# ACTION GOT: [1.         0.         0.         0.44447666], action type one hot: [1. 0. 0.]
#         nflx: Held, networth: 25260.393564641476, shares: 10
#        step reward: 2.4700069427490234
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.4444766640663147
# Step: 2041 ----------------------
# ACTION GOT: [0.5745694 0.        0.        2.6727011], action type one hot: [0.5745694 0.        0.       ]
#         nflx: Held, networth: 25799.725708663464, shares: 39
#        step reward: 9.633027076721191
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 2.672701120376587
# Step: 2042 ----------------------
# ACTION GOT: [0.       0.       0.356888 0.      ], action type one hot: [0.       0.       0.356888]
#         Tried to Sell. Unable.
#        step reward: 11.904285430908203
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2042 ----------------------
# ACTION GOT: [0.         0.07231282 1.         0.7766419 ], action type one hot: [0.         0.07231282 1.        ]
#         nflx: Sold 1 stock(s) for:25.26714324951172,networth: 25807.13572949171, shares: 38
#        step reward: 46.426713180541995
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.7766419053077698
# Step: 2043 ----------------------
# ACTION GOT: [1. 0. 1. 0.], action type one hot: [1. 0. 1.]
#         nflx: Held, networth: 25271.450712621212, shares: 10
#        step reward: -3.2128562927246094
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2043 ----------------------
# ACTION GOT: [0.69205904 0.62199193 1.         0.        ], action type one hot: [0.69205904 0.62199193 1.        ]
#         Tried to Sell. Unable.
#        step reward: -12.208853912353517
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.0
# Step: 2044 ----------------------
# ACTION GOT: [0.         0.60886866 0.         0.        ], action type one hot: [0.         0.60886866 0.        ]
# ACTION VALUE: 0.0
#         Tried to Buy. Unable.
#        step reward: -3.9742774963378906
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.0
# Step: 2044 ----------------------
# ACTION GOT: [0.49443525 1.         0.         1.0596721 ], action type one hot: [0.49443525 1.         0.        ]
# ACTION VALUE: 1.0596721172332764
#         nflx: Bought 1 stock(s) for:24.71428680419922, networth: 25833.45715969801, shares: 39
#        step reward: -15.102254486083984
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 1.0596721172332764
# Step: 2045 ----------------------
# ACTION GOT: [0.         1.         0.         0.52930665], action type one hot: [0. 1. 0.]
# ACTION VALUE: 0.5293066501617432
#         nflx: Bought 1 stock(s) for:24.042856216430664, networth: 25265.922148168087, shares: 11
#        step reward: -8.728597640991211
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.5293066501617432
# Step: 2045 ----------------------
# ACTION GOT: [0.2815968  1.         0.03626565 0.05051538], action type one hot: [0.2815968  1.         0.03626565]
# ACTION VALUE: 0.05051538348197937
#         Tried to Buy. Unable.
#        step reward: -34.041530799865725
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.05051538348197937
# Step: 2046 ----------------------
# ACTION GOT: [1.         0.7977238  0.40208676 0.40480015], action type one hot: [1.         0.7977238  0.40208676]
#         nflx: Held, networth: 25259.2078422904, shares: 11
#        step reward: -5.924284934997559
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.404800146818161
# Step: 2046 ----------------------
# ACTION GOT: [0.        0.        1.        2.3440032], action type one hot: [0. 0. 1.]
#         nflx: Sold 2 stock(s) for:23.628570556640625,networth: 25795.654247939587, shares: 37
#        step reward: -21.00428295135498
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 2.344003200531006
# Step: 2047 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25254.65070003271, shares: 11
#        step reward: 2.6148624420166016
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2047 ----------------------
# ACTION GOT: [1.         0.49525768 0.         2.0316215 ], action type one hot: [1.         0.49525768 0.        ]
#         nflx: Held, networth: 25779.497107207775, shares: 37
#        step reward: 8.795446395874023
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 2.0316214561462402
# Step: 2048 ----------------------
# ACTION GOT: [0.31108817 0.         0.         0.        ], action type one hot: [0.31108817 0.         0.        ]
#         nflx: Held, networth: 25256.662132680416, shares: 11
#        step reward: 3.370736885070801
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2048 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25786.2628352046, shares: 37
#        step reward: 11.337933158874511
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2049 ----------------------
# ACTION GOT: [1. 0. 0. 0.], action type one hot: [1. 0. 0.]
#         nflx: Held, networth: 25259.255007207394, shares: 11
#        step reward: 9.621831893920898
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2049 ----------------------
# ACTION GOT: [1. 0. 0. 0.], action type one hot: [1. 0. 0.]
#         nflx: Held, networth: 25794.98432224989, shares: 37
#        step reward: 32.36434364318848
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2050 ----------------------
# ACTION GOT: [0.62029344 1.         0.         0.        ], action type one hot: [0.62029344 1.         0.        ]
# ACTION VALUE: 0.0
#         Tried to Buy. Unable.
#        step reward: 31.214862442016603
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.0
# Step: 2050 ----------------------
# ACTION GOT: [0.         0.91663885 0.06826149 0.38098106], action type one hot: [0.         0.91663885 0.06826149]
# ACTION VALUE: 0.38098105788230896
#         Tried to Buy. Unable.
#        step reward: 104.99544639587403
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.38098105788230896
# Step: 2051 ----------------------
# ACTION GOT: [1.         0.4638127  1.         0.90169334], action type one hot: [1.        0.4638127 1.       ]
#         nflx: Held, networth: 25290.66784900427, shares: 11
#        step reward: -1.2461441040039063
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.9016933441162109
# Step: 2051 ----------------------
# ACTION GOT: [0.7279625 0.        0.        0.       ], action type one hot: [0.7279625 0.        0.       ]
#         nflx: Held, networth: 25900.645699203014, shares: 37
#        step reward: -4.191575622558594
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2052 ----------------------
# ACTION GOT: [0.         0.         1.         0.05137273], action type one hot: [0. 0. 1.]
#         Tried to Sell. Unable.
#        step reward: 2.165423583984375
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.051372725516557693
# Step: 2052 ----------------------
# ACTION GOT: [0.         0.         0.30602035 0.07689592], action type one hot: [0.         0.         0.30602035]
#         Tried to Sell. Unable.
#        step reward: 7.283697509765625
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.07689592242240906
# Step: 2053 ----------------------
# ACTION GOT: [0.         0.30506608 0.48325402 0.10238136], action type one hot: [0.         0.30506608 0.48325402]
#         Tried to Sell. Unable.
#        step reward: 6.39415283203125
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.10238136351108551
# Step: 2053 ----------------------
# ACTION GOT: [1.         0.0762215  0.         0.18378702], action type one hot: [1.        0.0762215 0.       ]
#         nflx: Held, networth: 25903.024254500866, shares: 37
#        step reward: 21.507604980468752
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.1837870180606842
# Step: 2054 ----------------------
# ACTION GOT: [1.        1.        0.        0.1951042], action type one hot: [1. 1. 0.]
#         nflx: Held, networth: 25296.293566167355, shares: 11
#        step reward: 14.34085807800293
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.1951041966676712
# Step: 2054 ----------------------
# ACTION GOT: [0.32878816 0.         0.         0.        ], action type one hot: [0.32878816 0.         0.        ]
#         nflx: Held, networth: 25919.568566024303, shares: 37
#        step reward: 48.23743171691895
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2055 ----------------------
# ACTION GOT: [0.81700253 0.1308519  0.20236036 0.        ], action type one hot: [0.81700253 0.1308519  0.20236036]
#         nflx: Held, networth: 25307.324995458126, shares: 11
#        step reward: 14.25914192199707
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2055 ----------------------
# ACTION GOT: [0.         0.02179591 0.         0.        ], action type one hot: [0.         0.02179591 0.        ]
# ACTION VALUE: 0.0
#         Tried to Buy. Unable.
#        step reward: 47.962568283081055
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 1, action value: 0.0
# Step: 2056 ----------------------
# ACTION GOT: [0. 0. 0. 0.], action type one hot: [0. 0. 0.]
#         nflx: Held, networth: 25318.293566167355, shares: 11
#        step reward: -11.766853713989258
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.0
# Step: 2056 ----------------------
# ACTION GOT: [1.         0.35241592 0.3814364  0.79228866], action type one hot: [1.         0.35241592 0.3814364 ]
#         nflx: Held, networth: 25993.568566024303, shares: 37
#        step reward: -39.57941703796387
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.7922886610031128
# Step: 2057 ----------------------
# ACTION GOT: [0.         0.19933331 0.77285093 0.0947655 ], action type one hot: [0.         0.19933331 0.77285093]
#         Tried to Sell. Unable.
#        step reward: -13.727986907958984
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 2, action value: 0.09476549923419952
# Step: 2057 ----------------------
# ACTION GOT: [1.        0.        0.9876156 0.3674233], action type one hot: [1.        0.        0.9876156]
#         nflx: Held, networth: 25963.122860610485, shares: 37
#        step reward: -46.17595596313477
# ACTION To STR: ['Hold', 'Buy', 'Sell'], action type: 0, action value: 0.36742329597473145

# %%
#PPO 
env = eval_model('kros',model_ppo,verbose=0)
fig = plot_history(env.history,(22, 12))
# Out:
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# iters: 155

# %%
#A2C
env_a = eval_model('kros',model_a2c,verbose=0)
fig_a = plot_history(env_a.history,(22, 12))
# Out:
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# iters: 155
