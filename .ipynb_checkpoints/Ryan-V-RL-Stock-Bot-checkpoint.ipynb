# %% [markdown]
# ## Stock Bot
# Okay Im gonna make a DIY stock trading, reinforcment learning bot on my own with preferably only tensorflow, numpy, and padas. I actually have no idea how to do that, sooo lets try it out!
#
# ### Planning
# I need to have the following items built
# - the environment
# - the agent
# - memory for the agent
# - the policy for the agent
# - the neural net for the agent
#
# TODO: Train and wth is wrong with the probabilities contain nAn for training

# %%
from tensorflow import keras
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import yfinance as yf
import gym_anytrading
import rl
from StockTradeEnv import FastTrainingStockTradeEnv
import quantstats as qs

# %% [markdown]
# ## Environment
# The environment will contain the observable variables:
#     -
#     -
# The environment will contain the avalible actions of:
#     -
#     -
#     -

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Input, Activation, Concatenate
from tensorflow.keras.optimizers import Adam
from stable_baselines3 import A2C
from stable_baselines3.a2c import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv

# Parallel environments
stks = ['sbux','nflx','tmus','adct','h','bngo','amzn','nio','fb','gme']#,'work']
env = DummyVecEnv([lambda: FastTrainingStockTradeEnv(ticker=stks[i],frame_bound=(100, 10000000), window_size=10,initial_balance=25000) for i in range(len(stks))])
# env = FastTrainingStockTradeEnv(ticker='work',frame_bound=(100, 10000000), window_size=10,initial_balance=25000)
# Out:
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
model = A2C(MlpPolicy, env, verbose=1)
# Out:
# Using cpu device

# %%
#TODO: WHEN I GET BACK run this, see how it goes, and modify reward system
#don't print too much, if you do, jupyter will crash
model = model.learn(total_timesteps=9000)
# Out:
# ------------------------------------
# | time/                 |          |
# |    fps                | 19463    |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -5.71    |
# |    explained_variance | -3.5e+06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 33       |
# |    std                | 1.01     |
# |    value_loss         | 53.5     |
# ------------------------------------

# %%
def eval_(stk_ticker):
    env = FastTrainingStockTradeEnv(ticker=stk_ticker,frame_bound=(100, 10000000), window_size=10,initial_balance=25000,verbose=2)
    observation = env.reset()
    itr = 0
    while True:
        observation = observation
        action, _states = model.predict(observation)
        observation, reward, done, info = env.step(action)
        itr+=1
        if done:
            print("info:", info)
            print("iters:",itr)
            break
    return env
            
def eval_rand(stk_ticker,iter_manual=30):
    env = FastTrainingStockTradeEnv(ticker=stk_ticker,frame_bound=(100, 10000000), window_size=10,initial_balance=25000,verbose=2)
    observation = env.reset()
    itr = 0
    while itr <= iter_manual:
        observation = observation
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        itr+=1
        if itr == iter_manual:
            print("info:", info)
            print("iters:",itr)
            break

# %%
env = eval_('work')
# Out:
# Step: 10 ----------------------
# Discouraging holding
#         work: Held, networth: 25000, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 11 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 12 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 13 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 14 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 15 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 16 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 17 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 18 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 19 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 20 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 21 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 22 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 23 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 24 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 25 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 26 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 27 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 28 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 29 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 30 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 31 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 32 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 33 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 34 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 35 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 36 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 37 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 38 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 39 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 40 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 41 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 42 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 43 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 44 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 45 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 46 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 47 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 48 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 49 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 50 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 51 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 52 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 53 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 54 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 55 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 56 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 57 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 58 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 59 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 60 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 61 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 62 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 63 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 64 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 65 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 66 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 67 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 68 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 69 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 70 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 71 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 72 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 73 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 74 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 75 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 76 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 77 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 78 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 79 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 80 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 81 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 82 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 83 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 84 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 85 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 86 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 87 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 88 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 89 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 90 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 91 ----------------------
#         Tried to Sell. Unable.
#        step reward: -2.0, og step reward: 0.0, add_to_step_reward: -2
# Step: 92 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 93 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 94 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 95 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 96 ----------------------
#         Tried to Sell. Unable.
#        step reward: -2.0, og step reward: 0.0, add_to_step_reward: -2
# Step: 97 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 98 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 99 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 100 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 101 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 102 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 103 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 104 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 105 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 106 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 107 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 108 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 109 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 110 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 111 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 112 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 113 ----------------------
# Discouraging holding
#         work: Held, networth: 25000.0, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 114 ----------------------
#         work: Bought 3 stock(s) for:25.31999969482422, networth: 25000.0, shares: 3
#        step reward: 0.0, og step reward: 0.0, add_to_step_reward: 0
# Step: 115 ----------------------
#         work: Held, networth: 25000.0, shares: 3
#        step reward: 10.840003967285156, og step reward: 8.130002975463867, add_to_step_reward: 2.710000991821289
# Step: 116 ----------------------
#         work: Held, networth: 25008.130002975464, shares: 3
#        step reward: 8.109994888305664, og step reward: 4.049995422363281, add_to_step_reward: 4.059999465942383
# Step: 117 ----------------------
#         work: Held, networth: 25012.179998397827, shares: 3
#        step reward: -1.0599956512451172, og step reward: -3.839996337890625, add_to_step_reward: 2.780000686645508
# Step: 118 ----------------------
#         work: Held, networth: 25008.340002059937, shares: 3
#        step reward: 7.379999160766602, og step reward: 3.4499988555908203, add_to_step_reward: 3.9300003051757812
# Step: 119 ----------------------
#         work: Held, networth: 25011.790000915527, shares: 3
#        step reward: -7.230003356933594, og step reward: -8.370002746582031, add_to_step_reward: 1.1399993896484375
# Step: 120 ----------------------
#         work: Held, networth: 25003.419998168945, shares: 3
#        step reward: -0.05999755859375, og step reward: -0.8999977111816406, add_to_step_reward: 0.8400001525878906
# Step: 121 ----------------------
#         work: Held, networth: 25002.520000457764, shares: 3
#        step reward: 2.3200035095214844, og step reward: 1.1100025177001953, add_to_step_reward: 1.210000991821289
# Step: 122 ----------------------
#         work: Held, networth: 25003.630002975464, shares: 3
#        step reward: -0.6700038909912109, og step reward: -1.410003662109375, add_to_step_reward: 0.7399997711181641
# Step: 123 ----------------------
#         work: Held, networth: 25002.219999313354, shares: 3
#        step reward: 5.739999771118164, og step reward: 3.75, add_to_step_reward: 1.989999771118164
# Step: 124 ----------------------
#         work: Held, networth: 25005.969999313354, shares: 3
#        step reward: 0.26999855041503906, og step reward: -1.2900009155273438, add_to_step_reward: 1.5599994659423828
# Step: 125 ----------------------
#         work: Held, networth: 25004.679998397827, shares: 3
#        step reward: 2.3200016021728516, og step reward: 0.5700016021728516, add_to_step_reward: 1.75
# Step: 126 ----------------------
#         work: Held, networth: 25005.25, shares: 3
#        step reward: 0.23000335693359375, og step reward: -1.1399974822998047, add_to_step_reward: 1.3700008392333984
# Step: 127 ----------------------
#         work: Held, networth: 25004.1100025177, shares: 3
#        step reward: 0.12999534606933594, og step reward: -0.9300041198730469, add_to_step_reward: 1.0599994659423828
# Step: 128 ----------------------
#         work: Held, networth: 25003.179998397827, shares: 3
#        step reward: 4.340005874633789, og step reward: 2.4600048065185547, add_to_step_reward: 1.8800010681152344
# Step: 129 ----------------------
#         work: Held, networth: 25005.640003204346, shares: 3
#        step reward: 2.240001678466797, og step reward: 0.2700004577636719, add_to_step_reward: 1.970001220703125
# Step: 130 ----------------------
#         work: Held, networth: 25005.91000366211, shares: 3
#        step reward: 3.3299942016601562, og step reward: 1.0199947357177734, add_to_step_reward: 2.309999465942383
# Step: 131 ----------------------
#         work: Held, networth: 25006.929998397827, shares: 3
#        step reward: 11.590005874633789, og step reward: 6.960004806518555, add_to_step_reward: 4.630001068115234
# Step: 132 ----------------------
#         work: Held, networth: 25013.890003204346, shares: 3
#        step reward: 9.46999740600586, og step reward: 3.6299972534179688, add_to_step_reward: 5.840000152587891
# Step: 133 ----------------------
#         work: Held, networth: 25017.520000457764, shares: 3
#        step reward: 6.240001678466797, og step reward: 0.3000011444091797, add_to_step_reward: 5.940000534057617
# Step: 134 ----------------------
#         work: Held, networth: 25017.820001602173, shares: 3
#        step reward: 4.940000534057617, og step reward: -0.75, add_to_step_reward: 5.690000534057617
# Step: 135 ----------------------
#         work: Held, networth: 25017.070001602173, shares: 3
#        step reward: 2.450002670288086, og step reward: -2.4299983978271484, add_to_step_reward: 4.880001068115234
# Step: 136 ----------------------
#         work: Held, networth: 25014.640003204346, shares: 3
#        step reward: 10.71999740600586, og step reward: 4.379997253417969, add_to_step_reward: 6.340000152587891
# Step: 137 ----------------------
#         work: Held, networth: 25019.020000457764, shares: 3
#        step reward: 5.020000457763672, og step reward: -0.9899997711181641, add_to_step_reward: 6.010000228881836
# Step: 138 ----------------------
#         work: Sold 3 stock(s) for:29.0, networth: 25018.030000686646, shares: 0
#        step reward: 29.81000328063965, og step reward: -6.989999771118164, add_to_step_reward: 36.80000305175781
# Step: 139 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 140 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 141 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 142 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 143 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 144 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 145 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 146 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 147 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 148 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 149 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 150 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 151 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 152 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 153 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 154 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 155 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 156 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 157 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 158 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 159 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 160 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 161 ----------------------
# Discouraging holding
#         work: Held, networth: 25011.040000915527, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 162 ----------------------
#         work: Bought 5 stock(s) for:34.209999084472656, networth: 25011.040000915527, shares: 5
#        step reward: 0.0, og step reward: 0.0, add_to_step_reward: 0
# Step: 163 ----------------------
#         work: Held, networth: 25011.040000915527, shares: 5
#        step reward: -1.019989013671875, og step reward: -0.8499908447265625, add_to_step_reward: -0.1699981689453125
# Step: 164 ----------------------
#         work: Held, networth: 25010.1900100708, shares: 5
#        step reward: -12.590007781982422, og step reward: -10.350008010864258, add_to_step_reward: -2.239999771118164
# Step: 165 ----------------------
#         work: Held, networth: 24999.840002059937, shares: 5
#        step reward: 2.8600025177001953, og step reward: 4.250001907348633, add_to_step_reward: -1.3899993896484375
# Step: 166 ----------------------
#         work: Held, networth: 25004.090003967285, shares: 5
#        step reward: -3.1300048828125, og step reward: -1.4500045776367188, add_to_step_reward: -1.6800003051757812
# Step: 167 ----------------------
#         work: Held, networth: 25002.63999938965, shares: 5
#        step reward: -11.63998794555664, og step reward: -8.299989700317383, add_to_step_reward: -3.339998245239258
# Step: 168 ----------------------
#         work: Held, networth: 24994.34000968933, shares: 5
#        step reward: -2.0200023651123047, og step reward: 1.099996566772461, add_to_step_reward: -3.1199989318847656
# Step: 169 ----------------------
#         work: Held, networth: 24995.440006256104, shares: 5
#        step reward: -3.3000030517578125, og step reward: -0.15000343322753906, add_to_step_reward: -3.1499996185302734
# Step: 170 ----------------------
#         work: Held, networth: 24995.290002822876, shares: 5
#        step reward: -7.649999618530273, og step reward: -3.75, add_to_step_reward: -3.8999996185302734
# Step: 171 ----------------------
#         work: Held, networth: 24991.540002822876, shares: 5
#        step reward: 0.9600086212158203, og step reward: 4.050006866455078, add_to_step_reward: -3.089998245239258
# Step: 172 ----------------------
#         work: Bought 3 stock(s) for:31.479999542236328, networth: 24995.59000968933, shares: 8
#        step reward: 1.7999935150146484, og step reward: 1.7999935150146484, add_to_step_reward: 0
# Step: 173 ----------------------
#         work: Held, networth: 24997.390003204346, shares: 8
#        step reward: 24.84001922607422, og step reward: 22.08001708984375, add_to_step_reward: 2.7600021362304688
# Step: 174 ----------------------
#         work: Held, networth: 25019.47002029419, shares: 8
#        step reward: 0.7799911499023438, og step reward: -1.760009765625, add_to_step_reward: 2.5400009155273438
# Step: 175 ----------------------
#         work: Held, networth: 25017.710010528564, shares: 8
#        step reward: 0.9199981689453125, og step reward: -1.44000244140625, add_to_step_reward: 2.3600006103515625
# Step: 176 ----------------------
#         work: Held, networth: 25016.27000808716, shares: 8
#        step reward: -1.4200172424316406, og step reward: -3.360015869140625, add_to_step_reward: 1.9399986267089844
# Step: 177 ----------------------
#         work: Held, networth: 25012.909992218018, shares: 8
#        step reward: -7.5099945068359375, og step reward: -8.399993896484375, add_to_step_reward: 0.8899993896484375
# Step: 178 ----------------------
#         work: Held, networth: 25004.509998321533, shares: 8
#        step reward: -1.3600006103515625, og step reward: -2.0, add_to_step_reward: 0.6399993896484375
# Step: 179 ----------------------
#         work: Held, networth: 25002.509998321533, shares: 8
#        step reward: -3.9499855041503906, og step reward: -4.079986572265625, add_to_step_reward: 0.13000106811523438
# Step: 180 ----------------------
#         work: Held, networth: 24998.430011749268, shares: 8
#        step reward: 4.630001068115234, og step reward: 4.0, add_to_step_reward: 0.6300010681152344
# Step: 181 ----------------------
#         work: Held, networth: 25002.430011749268, shares: 8
#        step reward: 11.250003814697266, og step reward: 9.44000244140625, add_to_step_reward: 1.8100013732910156
# Step: 182 ----------------------
#         work: Held, networth: 25011.870014190674, shares: 8
#        step reward: -4.310001373291016, og step reward: -5.44000244140625, add_to_step_reward: 1.1300010681152344
# Step: 183 ----------------------
#         work: Held, networth: 25006.430011749268, shares: 8
#        step reward: -13.899999618530273, og step reward: -13.360000610351562, add_to_step_reward: -0.5399990081787109
# Step: 184 ----------------------
#         work: Sold 3 stock(s) for:30.350000381469727, networth: 24993.070011138916, shares: 5
#        step reward: -16.01999282836914, og step reward: -4.720001220703125, add_to_step_reward: -11.299991607666016
# Step: 185 ----------------------
#         work: Held, networth: 24988.350009918213, shares: 5
#        step reward: -4.910005569458008, og step reward: -3.150005340576172, add_to_step_reward: -1.760000228881836
# Step: 186 ----------------------
#         work: Bought 3 stock(s) for:29.3700008392334, networth: 24985.200004577637, shares: 8
#        step reward: -1.7499923706054688, og step reward: -1.7499923706054688, add_to_step_reward: 0
# Step: 187 ----------------------
#         work: Held, networth: 24983.45001220703, shares: 8
#        step reward: -5.580007553100586, og step reward: -4.9600067138671875, add_to_step_reward: -0.6200008392333984
# Step: 188 ----------------------
#         work: Held, networth: 24978.490005493164, shares: 8
#        step reward: -1.9699974060058594, og step reward: -1.1999969482421875, add_to_step_reward: -0.7700004577636719
# Step: 189 ----------------------
#         work: Sold 3 stock(s) for:28.770000457763672, networth: 24977.290008544922, shares: 5
#        step reward: -4.640003204345703, og step reward: 1.3600006103515625, add_to_step_reward: -6.000003814697266
# Step: 190 ----------------------
#         work: Held, networth: 24978.650009155273, shares: 5
#        step reward: 4.079992294311523, og step reward: 3.899993896484375, add_to_step_reward: 0.17999839782714844
# Step: 191 ----------------------
#         work: Sold 4 stock(s) for:30.5, networth: 24982.550003051758, shares: 1
#        step reward: 16.04999542236328, og step reward: 4.750003814697266, add_to_step_reward: 11.299991607666016
# Step: 192 ----------------------
#         work: Held, networth: 24987.300006866455, shares: 1
#        step reward: 1.210000991821289, og step reward: 0.04000091552734375, add_to_step_reward: 1.1700000762939453
# Step: 193 ----------------------
#         work: Held, networth: 24987.340007781982, shares: 1
#        step reward: 0.10999870300292969, og step reward: -0.5300006866455078, add_to_step_reward: 0.6399993896484375
# Step: 194 ----------------------
#         work: Held, networth: 24986.810007095337, shares: 1
#        step reward: 0.7999992370605469, og step reward: 0.07999992370605469, add_to_step_reward: 0.7199993133544922
# Step: 195 ----------------------
#         work: Held, networth: 24986.890007019043, shares: 1
#        step reward: -1.5599994659423828, og step reward: -1.1399993896484375, add_to_step_reward: -0.4200000762939453
# Step: 196 ----------------------
#         work: Held, networth: 24985.750007629395, shares: 1
#        step reward: -2.0799999237060547, og step reward: -0.8299999237060547, add_to_step_reward: -1.25
# Step: 197 ----------------------
#         work: Held, networth: 24984.92000770569, shares: 1
#        step reward: -2.270000457763672, og step reward: -0.5100002288818359, add_to_step_reward: -1.760000228881836
# Step: 198 ----------------------
#         work: Held, networth: 24984.410007476807, shares: 1
#        step reward: -1.2800006866455078, og step reward: 0.23999977111816406, add_to_step_reward: -1.5200004577636719
# Step: 199 ----------------------
#         work: Held, networth: 24984.650007247925, shares: 1
#        step reward: -0.7400016784667969, og step reward: 0.3899993896484375, add_to_step_reward: -1.1300010681152344
# Step: 200 ----------------------
#         work: Held, networth: 24985.040006637573, shares: 1
#        step reward: -0.8899993896484375, og step reward: 0.12000083923339844, add_to_step_reward: -1.010000228881836
# Step: 201 ----------------------
#         work: Held, networth: 24985.160007476807, shares: 1
#        step reward: -1.2500019073486328, og step reward: -0.12000083923339844, add_to_step_reward: -1.1300010681152344
# Step: 202 ----------------------
#         work: Held, networth: 24985.040006637573, shares: 1
#        step reward: -0.7900009155273438, og step reward: 0.1700000762939453, add_to_step_reward: -0.9600009918212891
# Step: 203 ----------------------
#         work: Held, networth: 24985.210006713867, shares: 1
#        step reward: -0.6400012969970703, og step reward: 0.15999984741210938, add_to_step_reward: -0.8000011444091797
# Step: 204 ----------------------
#         work: Held, networth: 24985.37000656128, shares: 1
#        step reward: 2.019998550415039, og step reward: 1.4099998474121094, add_to_step_reward: 0.6099987030029297
# Step: 205 ----------------------
#         work: Held, networth: 24986.78000640869, shares: 1
#        step reward: -1.1900005340576172, og step reward: -0.8999996185302734, add_to_step_reward: -0.29000091552734375
# Step: 206 ----------------------
#         work: Held, networth: 24985.88000679016, shares: 1
#        step reward: -1.8699989318847656, og step reward: -0.7899990081787109, add_to_step_reward: -1.0799999237060547
# Step: 207 ----------------------
#         work: Held, networth: 24985.090007781982, shares: 1
#        step reward: -0.5200023651123047, og step reward: 0.279998779296875, add_to_step_reward: -0.8000011444091797
# Step: 208 ----------------------
#         work: Sold 1 stock(s) for:30.229999542236328, networth: 24985.37000656128, shares: 0
#        step reward: 10.259986877441406, og step reward: 1.6599998474121094, add_to_step_reward: 8.599987030029297
# Step: 209 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 210 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 211 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 212 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 213 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 214 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 215 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 216 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 217 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 218 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 219 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 220 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 221 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 222 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 223 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 224 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 225 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 226 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 227 ----------------------
#         Tried to Sell. Unable.
#        step reward: -2.0, og step reward: 0.0, add_to_step_reward: -2
# Step: 228 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 229 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 230 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 231 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 232 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 233 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 234 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 235 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 236 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 237 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 238 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 239 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 240 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 241 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 242 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 243 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 244 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 245 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 246 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 247 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 248 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 249 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 250 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 251 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 252 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 253 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 254 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 255 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 256 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 257 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 258 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 259 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 260 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 261 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 262 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 263 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 264 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 265 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 266 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 267 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 268 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 269 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 270 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 271 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 272 ----------------------
# Discouraging holding
#         work: Held, networth: 24987.03000640869, shares: 0
#        step reward: -10.0, og step reward: 0.0, add_to_step_reward: -10
# Step: 273 ----------------------
#         work: Bought 3 stock(s) for:40.66999816894531, networth: 24987.03000640869, shares: 3
#        step reward: 0.0, og step reward: 0.0, add_to_step_reward: 0
# Step: 274 ----------------------
#         work: Held, networth: 24987.03000640869, shares: 3
#        step reward: 8.840011596679688, og step reward: 6.630008697509766, add_to_step_reward: 2.210002899169922
# Step: 275 ----------------------
#         work: Held, networth: 24993.6600151062, shares: 3
#        step reward: 6.049999237060547, og step reward: 2.8799972534179688, add_to_step_reward: 3.170001983642578
# Step: 276 ----------------------
#         work: Held, networth: 24996.54001235962, shares: 3
#        step reward: -1.3500022888183594, og step reward: -3.390003204345703, add_to_step_reward: 2.0400009155273438
# Step: 277 ----------------------
#         work: Bought 1 stock(s) for:42.5099983215332, networth: 24993.150009155273, shares: 4
#        step reward: -0.6000022888183594, og step reward: -0.6000022888183594, add_to_step_reward: 0
# Step: 278 ----------------------
#         work: Held, networth: 24992.550006866455, shares: 4
#        step reward: 1.4500045776367188, og step reward: 1.160003662109375, add_to_step_reward: 0.29000091552734375
# Step: 279 ----------------------
#         work: Held, networth: 24993.710010528564, shares: 4
#        step reward: -0.3099937438964844, og step reward: -0.4799957275390625, add_to_step_reward: 0.17000198364257812
# Step: 280 ----------------------
#         work: Held, networth: 24993.230014801025, shares: 4
#        step reward: 1.9199943542480469, og step reward: 1.399993896484375, add_to_step_reward: 0.5200004577636719
# Step: 281 ----------------------
#         work: Held, networth: 24994.63000869751, shares: 4
#        step reward: -4.17999267578125, og step reward: -3.7599945068359375, add_to_step_reward: -0.4199981689453125
# Step: 282 ----------------------
#         work: Held, networth: 24990.870014190674, shares: 4
#        step reward: 0.7299995422363281, og step reward: 0.9199981689453125, add_to_step_reward: -0.18999862670898438
# Step: 283 ----------------------
#         work: Held, networth: 24991.79001235962, shares: 4
#        step reward: -0.5899887084960938, og step reward: -0.3199920654296875, add_to_step_reward: -0.26999664306640625
# Step: 284 ----------------------
#         work: Held, networth: 24991.47002029419, shares: 4
#        step reward: -0.170013427734375, og step reward: 0.079986572265625, add_to_step_reward: -0.25
# Step: 285 ----------------------
#         work: Held, networth: 24991.550006866455, shares: 4
#        step reward: -1.1499824523925781, og step reward: -0.7199859619140625, add_to_step_reward: -0.4299964904785156
# Step: 286 ----------------------
#         work: Held, networth: 24990.83002090454, shares: 4
#        step reward: 2.2199974060058594, og step reward: 2.1199951171875, add_to_step_reward: 0.10000228881835938
# Step: 287 ----------------------
#         work: Held, networth: 24992.95001602173, shares: 4
#        step reward: -0.24999618530273438, og step reward: -0.279998779296875, add_to_step_reward: 0.030002593994140625
# Step: 288 ----------------------
#         work: Held, networth: 24992.67001724243, shares: 4
#        step reward: 1.2800025939941406, og step reward: 1.0, add_to_step_reward: 0.2800025939941406
# Step: 289 ----------------------
#         work: Held, networth: 24993.67001724243, shares: 4
#        step reward: -0.8200035095214844, og step reward: -0.8800048828125, add_to_step_reward: 0.060001373291015625
# Step: 290 ----------------------
#         work: Held, networth: 24992.79001235962, shares: 4
#        step reward: 1.6100082397460938, og step reward: 1.2400054931640625, add_to_step_reward: 0.37000274658203125
# Step: 291 ----------------------
#         work: Held, networth: 24994.030017852783, shares: 4
#        step reward: -1.2299957275390625, og step reward: -1.279998779296875, add_to_step_reward: 0.0500030517578125
# Step: 292 ----------------------
#         work: Held, networth: 24992.750019073486, shares: 4
#        step reward: 0.5000038146972656, og step reward: 0.3600006103515625, add_to_step_reward: 0.14000320434570312
# Step: 293 ----------------------
#         work: Held, networth: 24993.110019683838, shares: 4
#        step reward: -1.55999755859375, og step reward: -1.3600006103515625, add_to_step_reward: -0.1999969482421875
# Step: 294 ----------------------
#         work: Held, networth: 24991.750019073486, shares: 4
#        step reward: -0.5499954223632812, og step reward: -0.279998779296875, add_to_step_reward: -0.26999664306640625
# Step: 295 ----------------------
#         work: Held, networth: 24991.47002029419, shares: 4
#        step reward: 0.18000411987304688, og step reward: 0.3600006103515625, add_to_step_reward: -0.17999649047851562
# Step: 296 ----------------------
#         work: Held, networth: 24991.83002090454, shares: 4
#        step reward: -0.6299972534179688, og step reward: -0.3600006103515625, add_to_step_reward: -0.26999664306640625
# Step: 297 ----------------------
#         work: Held, networth: 24991.47002029419, shares: 4
#        step reward: -1.5199966430664062, og step reward: -1.0, add_to_step_reward: -0.5199966430664062
# Step: 298 ----------------------
#         work: Held, networth: 24990.47002029419, shares: 4
#        step reward: -0.420013427734375, og step reward: 0.079986572265625, add_to_step_reward: -0.5
# Step: 299 ----------------------
#         work: Held, networth: 24990.550006866455, shares: 4
#        step reward: -1.5999870300292969, og step reward: -0.8799896240234375, add_to_step_reward: -0.7199974060058594
# Step: 300 ----------------------
#         work: Held, networth: 24989.67001724243, shares: 4
#        step reward: 0.92999267578125, og step reward: 1.3199920654296875, add_to_step_reward: -0.3899993896484375
# Step: 301 ----------------------
#         work: Held, networth: 24990.99000930786, shares: 4
#        step reward: 0.7599983215332031, og step reward: 0.9199981689453125, add_to_step_reward: -0.15999984741210938
# Step: 302 ----------------------
#         work: Held, networth: 24991.910007476807, shares: 4
#        step reward: -1.5599937438964844, og step reward: -1.1199951171875, add_to_step_reward: -0.4399986267089844
# Step: 303 ----------------------
#         work: Bought 3 stock(s) for:42.13999938964844, networth: 24990.79001235962, shares: 7
#        step reward: 0.279998779296875, og step reward: 0.279998779296875, add_to_step_reward: 0
# Step: 304 ----------------------
#         work: Held, networth: 24991.070011138916, shares: 7
#        step reward: 1.20001220703125, og step reward: 1.0500106811523438, add_to_step_reward: 0.15000152587890625
# Step: 305 ----------------------
#         work: Held, networth: 24992.12002182007, shares: 7
#        step reward: -2.8100204467773438, og step reward: -2.5900192260742188, add_to_step_reward: -0.220001220703125
# Step: 306 ----------------------
#         work: Held, networth: 24989.530002593994, shares: 7
#        step reward: -1.17999267578125, og step reward: -0.8399925231933594, add_to_step_reward: -0.3400001525878906
# Step: 307 ----------------------
#         work: Held, networth: 24988.6900100708, shares: 7
#        step reward: 1.8200035095214844, og step reward: 1.8900032043457031, add_to_step_reward: -0.06999969482421875
# Step: 308 ----------------------
#         work: Held, networth: 24990.580013275146, shares: 7
#        step reward: 4.410011291503906, og step reward: 3.9200096130371094, add_to_step_reward: 0.4900016784667969
# Step: 309 ----------------------
#         work: Held, networth: 24994.500022888184, shares: 7
#        step reward: -1.1900215148925781, og step reward: -1.4700202941894531, add_to_step_reward: 0.279998779296875
# Step: 310 ----------------------
#         work: Held, networth: 24993.030002593994, shares: 7
#        step reward: 2.120025634765625, og step reward: 1.6100234985351562, add_to_step_reward: 0.5100021362304688
# Step: 311 ----------------------
#         work: Held, networth: 24994.64002609253, shares: 7
#        step reward: 0.26998138427734375, og step reward: -0.21001815795898438, add_to_step_reward: 0.4799995422363281
# Step: 312 ----------------------
#         work: Held, networth: 24994.43000793457, shares: 7
#        step reward: 1.7599983215332031, og step reward: 1.1199989318847656, add_to_step_reward: 0.6399993896484375
# Step: 313 ----------------------
#         work: Held, networth: 24995.550006866455, shares: 7
#        step reward: -5.1999969482421875, og step reward: -5.109996795654297, add_to_step_reward: -0.09000015258789062
# Step: 314 ----------------------
#         work: Held, networth: 24990.4400100708, shares: 7
#        step reward: 1.4300193786621094, og step reward: 1.33001708984375, add_to_step_reward: 0.10000228881835938
# Step: 315 ----------------------
#         work: Held, networth: 24991.770027160645, shares: 7
#        step reward: -0.4600257873535156, og step reward: -0.4900245666503906, add_to_step_reward: 0.029998779296875
# info: {'networth': 24991.280002593994, 'action_type': 'Hold', 'action_value': 4, 'tick': 316, 'shares_owned': 7, 'price': 42.16999816894531, 'reward': -0.4600257873535156}
# iters: 306
# /Users/ryandu_1/miniforge3/envs/tfenv/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def plt_actions(history,plot_loc):
    acth = np.array([history['action_type']]).reshape(-1)
    shares = np.array([history['shares_owned']]).reshape(-1)
    hold_x=[]
    buy_x=[]
    sell_x=[]
    hold_y=[]
    buy_y=[]
    sell_y=[]
    for i in range(len(acth)):
        if acth[i] == "Hold":
            hold_x.append(i)
            hold_y.append(shares[i-1])
        elif acth[i] == "Buy":
            buy_x.append(i)
            buy_y.append(shares[i-1])
        elif acth[i] == "Sell":
            sell_x.append(i)
            sell_y.append(shares[i-1])
    plot_loc.scatter(hold_x,hold_y,c='r',label='Hold')
    plot_loc.scatter(buy_x,buy_y,c='g',label='Buy')
    plot_loc.scatter(sell_x,sell_y,c='y',label='Sell')
    plot_loc.legend()
    
def plot_history(history,size):
    fig, axs = plt.subplots(3, 2)  # a figure with a 2x2 grid of Axes
    axs[0,0].plot(history['networth'],'r')
    axs[0,0].set_title("Networth")
    axs[0,1].plot(history['shares_owned'],'b',label="Shares Owned")
    plt_actions(history,axs[0,1])
    axs[0,1].set_title("Shares Owned")
    axs[1,0].plot(history['price'],'g')
    axs[1,0].set_title("Stock Price")
    axs[1,1].plot(history['reward'],'y')
    axs[1,1].set_title("Step Reward")
    axs[2,0].hist(history['action_type'])
    axs[2,0].set_title("Action Porportion Hist")
    fig.set_size_inches(size)
    return fig
fig = plot_history(env.history,(22, 12))

# %%
history.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f5ea13a3ebfd> in <module>
# ----> 1 history.keys()
#
# NameError: name 'history' is not defined

# %%
a_s_scatter[1]
